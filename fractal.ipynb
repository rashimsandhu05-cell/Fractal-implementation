# %%
import turtle


def draw_triangle(points, colour):
    """Draw a filled triangle using three points."""
    
    turtle.fillcolor(colour)
    turtle.penup()
    turtle.goto(points[0])
    turtle.pendown()

    turtle.begin_fill()

    for point in points[1:]:
        turtle.goto(point)

    turtle.goto(points[0])
    turtle.end_fill()


def midpoint(point1, point2):
    """Return the midpoint between two points."""

    return (
        (point1[0] + point2[0]) / 2,
        (point1[1] + point2[1]) / 2
    )


def sierpinski(points, degree):
    """Recursively draw a Sierpinski Triangle."""

    colours = [
        "blue",
        "red",
        "green",
        "yellow",
        "purple",
        "orange"
    ]

    draw_triangle(points, colours[degree % len(colours)])

    if degree > 0:

        # Top triangle
        sierpinski(
            [
                points[0],
                midpoint(points[0], points[1]),
                midpoint(points[0], points[2])
            ],
            degree - 1
        )

        # Bottom-left triangle
        sierpinski(
            [
                points[1],
                midpoint(points[0], points[1]),
                midpoint(points[1], points[2])
            ],
            degree - 1
        )

        # Bottom-right triangle
        sierpinski(
            [
                points[2],
                midpoint(points[0], points[2]),
                midpoint(points[1], points[2])
            ],
            degree - 1
        )


# Set up the turtle window
screen = turtle.Screen()
screen.title("Sierpinski Triangle Fractal")
screen.bgcolor("white")

# Make drawing faster
turtle.speed(0)
turtle.hideturtle()

# The three corners of the main triangle
points = [
    (-300, -250),
    (0, 300),
    (300, -250)
]

# Recursion depth
degree = 5

# Draw the fractal
sierpinski(points, degree)

# Keep the window open
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import turtle
#       2
#       3
#       4 def draw_triangle(points, colour):
#
# File /opt/homebrew/Cellar/python@3.14/3.14.6/Frameworks/Python.framework/Versions/3.14/lib/python3.14/turtle.py:101
#       1 #
#       2 # turtle.py: a Tkinter based turtle graphics module for Python
#       3 # Version 1.1b - 4. 5. 2009
#    (...)     21 #    misrepresented as being the original software.
#      22 # 3. This notice may not be removed or altered from any source distribution.
#      24 """
#      25 Turtle graphics is a popular way for introducing programming to
#      26 kids. It was part of the original Logo programming language developed
#    (...)     98 extensions in mind. These will be commented and documented elsewhere.
#      99 """
# --> 101 import tkinter as TK
#     102 import types
#     103 import math
#
# File /opt/homebrew/Cellar/python@3.14/3.14.6/Frameworks/Python.framework/Versions/3.14/lib/python3.14/tkinter/__init__.py:38
#      35 import sys
#      36 import types
# ---> 38 import _tkinter # If this fails your Python may not be configured for Tk
#      39 TclError = _tkinter.TclError
#      40 from tkinter.constants import *
#
# ModuleNotFoundError: No module named '_tkinter'
